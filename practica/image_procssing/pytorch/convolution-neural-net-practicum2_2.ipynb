# %%
# Define the train-validation split ratio (e.g., 0.8 for 80% training, 0.2 for 20% validation)
train_ratio = 0.8
train_size = int(train_ratio * len(dataset))
val_size = len(dataset) - train_size

# Split the dataset into train and validation sets
train_dataset, val_dataset = torch.utils.data.random_split(dataset, [train_size, val_size])

# Create dataloaders for train and validation sets
train_dataloader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=32, shuffle=False)

# Define the CNN model
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(3, 6, 5)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.fc1 = nn.Linear(16 * 13 * 13, 120)
        self.drop1 = nn.Dropout(p=0.2)
        self.fc2 = nn.Linear(120, 84)
        self.drop2 = nn.Dropout(p=0.2)
        self.fc3 = nn.Linear(84, 2)
        
    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        #x = x.view(x.size(0), -1)
        x = x.view(-1, 16 * 13 * 13)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        return self.fc3(x)    

# Initialize the CNN model
model = CNN()

# Define the loss function
criterion = nn.CrossEntropyLoss()

# Define the optimizer
optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

# Set the number of epochs
num_epochs = 100

# Training loop
for epoch in range(num_epochs):
    # Training
    model.train()
    running_loss = 0.0
    for images, labels in train_dataloader:
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
    epoch_loss = running_loss / len(train_dataloader)
    
    # Validation
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for images, labels in val_dataloader:
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    accuracy = correct / total

    if (epoch + 1) % 10 == 0:
        print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {epoch_loss:.4f}, Accuracy: {accuracy:.4f}")
# Out:
#   Cell In[5], line 132
#     #print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {epoch_loss:.4f}, Accuracy: {accuracy:.4f}")
#                                                                                                ^
# SyntaxError: incomplete input

# %%
import matplotlib.pyplot as plt
import torch
import torch.optim as optim
import torchvision
import torch.nn.functional as F
import torchvision.transforms as T
from torchvision.io import ImageReadMode, read_image
from torch import nn
from torch.utils.data import Dataset, DataLoader
from PIL import Image
import glob

forestDirectory = '../../pics/2750/Forest'
forest_images = glob.glob(forestDirectory + '/*.jpg')

industrialDirectory = '../../pics/2750/Industrial'
industrial_images = glob.glob(industrialDirectory + '/*.jpg')

print(forest_images)
print(industrial_images)

industrial_labels = [0] * len(industrial_images)  # label 0 for industrial images
forest_labels = [1] * len(forest_images)  # label 1 for forest images

X = industrial_images + forest_images
Y = industrial_labels + forest_labels

dataset_path = "../../pics/2750/"
transform = ToTensor()
dataset = ImageFolder(dataset_path, transform=transform)

dataset.class_to_idx


# Define the transformations
transform = T.Compose([
    T.ToTensor(),
    T.Resize((32, 32)),  # Resize the images to a consistent size
    T.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))  # Normalize the image tensors
])

# Create the dataset
dataset = ImageDataset(X, Y, transform=transform).__getitem__
dataset.shape
# Out:
# ['../../pics/2750/Forest\\Forest_1.jpg', '../../pics/2750/Forest\\Forest_10.jpg', '../../pics/2750/Forest\\Forest_100.jpg', '../../pics/2750/Forest\\Forest_1000.jpg', '../../pics/2750/Forest\\Forest_1001.jpg', '../../pics/2750/Forest\\Forest_1002.jpg', '../../pics/2750/Forest\\Forest_1003.jpg', '../../pics/2750/Forest\\Forest_1004.jpg', '../../pics/2750/Forest\\Forest_1005.jpg', '../../pics/2750/Forest\\Forest_1006.jpg', '../../pics/2750/Forest\\Forest_1007.jpg', '../../pics/2750/Forest\\Forest_1008.jpg', '../../pics/2750/Forest\\Forest_1009.jpg', '../../pics/2750/Forest\\Forest_101.jpg', '../../pics/2750/Forest\\Forest_1010.jpg', '../../pics/2750/Forest\\Forest_1011.jpg', '../../pics/2750/Forest\\Forest_1012.jpg', '../../pics/2750/Forest\\Forest_1013.jpg', '../../pics/2750/Forest\\Forest_1014.jpg', '../../pics/2750/Forest\\Forest_1015.jpg', '../../pics/2750/Forest\\Forest_1016.jpg', '../../pics/2750/Forest\\Forest_1017.jpg', '../../pics/2750/Forest\\Forest_1018.jpg', '../../pics/2750/Forest\\Forest_1019.jpg', '../../pics/2750/Forest\\Forest_102.jpg', '../../pics/2750/Forest\\Forest_1020.jpg', '../../pics/2750/Forest\\Forest_1021.jpg', '../../pics/2750/Forest\\Forest_1022.jpg', '../../pics/2750/Forest\\Forest_1023.jpg', '../../pics/2750/Forest\\Forest_1024.jpg', '../../pics/2750/Forest\\Forest_1025.jpg', '../../pics/2750/Forest\\Forest_1026.jpg', '../../pics/2750/Forest\\Forest_1027.jpg', '../../pics/2750/Forest\\Forest_1028.jpg', '../../pics/2750/Forest\\Forest_1029.jpg', '../../pics/2750/Forest\\Forest_103.jpg', '../../pics/2750/Forest\\Forest_1030.jpg', '../../pics/2750/Forest\\Forest_1031.jpg', '../../pics/2750/Forest\\Forest_1032.jpg', '../../pics/2750/Forest\\Forest_1033.jpg', '../../pics/2750/Forest\\Forest_1034.jpg', '../../pics/2750/Forest\\Forest_1035.jpg', '../../pics/2750/Forest\\Forest_1036.jpg', '../../pics/2750/Forest\\Forest_1037.jpg', '../../pics/2750/Forest\\Forest_1038.jpg', '../../pics/2750/Forest\\Forest_1039.jpg', '../../pics/2750/Forest\\Forest_104.jpg', '../../pics/2750/Forest\\Forest_1040.jpg', '../../pics/2750/Forest\\Forest_1041.jpg', '../../pics/2750/Forest\\Forest_1042.jpg', '../../pics/2750/Forest\\Forest_1043.jpg', '../../pics/2750/Forest\\Forest_1044.jpg', '../../pics/2750/Forest\\Forest_1045.jpg', '../../pics/2750/Forest\\Forest_1046.jpg', '../../pics/2750/Forest\\Forest_1047.jpg', '../../pics/2750/Forest\\Forest_1048.jpg', '../../pics/2750/Forest\\Forest_1049.jpg', '../../pics/2750/Forest\\Forest_105.jpg', '../../pics/2750/Forest\\Forest_1050.jpg', '../../pics/2750/Forest\\Forest_1051.jpg', '../../pics/2750/Forest\\Forest_1052.jpg', '../../pics/2750/Forest\\Forest_1053.jpg', '../../pics/2750/Forest\\Forest_1054.jpg', '../../pics/2750/Forest\\Forest_1055.jpg', '../../pics/2750/Forest\\Forest_1056.jpg', '../../pics/2750/Forest\\Forest_1057.jpg', '../../pics/2750/Forest\\Forest_1058.jpg', '../../pics/2750/Forest\\Forest_1059.jpg', '../../pics/2750/Forest\\Forest_106.jpg', '../../pics/2750/Forest\\Forest_1060.jpg', '../../pics/2750/Forest\\Forest_1061.jpg', '../../pics/2750/Forest\\Forest_1062.jpg', '../../pics/2750/Forest\\Forest_1063.jpg', '../../pics/2750/Forest\\Forest_1064.jpg', '../../pics/2750/Forest\\Forest_1065.jpg', '../../pics/2750/Forest\\Forest_1066.jpg', '../../pics/2750/Forest\\Forest_1067.jpg', '../../pics/2750/Forest\\Forest_1068.jpg', '../../pics/2750/Forest\\Forest_1069.jpg', '../../pics/2750/Forest\\Forest_107.jpg', '../../pics/2750/Forest\\Forest_1070.jpg', '../../pics/2750/Forest\\Forest_1071.jpg', '../../pics/2750/Forest\\Forest_1072.jpg', '../../pics/2750/Forest\\Forest_1073.jpg', '../../pics/2750/Forest\\Forest_1074.jpg', '../../pics/2750/Forest\\Forest_1075.jpg', '../../pics/2750/Forest\\Forest_1076.jpg', '../../pics/2750/Forest\\Forest_1077.jpg', '../../pics/2750/Forest\\Forest_1078.jpg', '../../pics/2750/Forest\\Forest_1079.jpg', '../../pics/2750/Forest\\Forest_108.jpg', '../../pics/2750/Forest\\Forest_1080.jpg', '../../pics/2750/Forest\\Forest_1081.jpg', '../../pics/27 ...
# ['../../pics/2750/Industrial\\Industrial_1.jpg', '../../pics/2750/Industrial\\Industrial_10.jpg', '../../pics/2750/Industrial\\Industrial_100.jpg', '../../pics/2750/Industrial\\Industrial_1000.jpg', '../../pics/2750/Industrial\\Industrial_1001.jpg', '../../pics/2750/Industrial\\Industrial_1002.jpg', '../../pics/2750/Industrial\\Industrial_1003.jpg', '../../pics/2750/Industrial\\Industrial_1004.jpg', '../../pics/2750/Industrial\\Industrial_1005.jpg', '../../pics/2750/Industrial\\Industrial_1006.jpg', '../../pics/2750/Industrial\\Industrial_1007.jpg', '../../pics/2750/Industrial\\Industrial_1008.jpg', '../../pics/2750/Industrial\\Industrial_1009.jpg', '../../pics/2750/Industrial\\Industrial_101.jpg', '../../pics/2750/Industrial\\Industrial_1010.jpg', '../../pics/2750/Industrial\\Industrial_1011.jpg', '../../pics/2750/Industrial\\Industrial_1012.jpg', '../../pics/2750/Industrial\\Industrial_1013.jpg', '../../pics/2750/Industrial\\Industrial_1014.jpg', '../../pics/2750/Industrial\\Industrial_1015.jpg', '../../pics/2750/Industrial\\Industrial_1016.jpg', '../../pics/2750/Industrial\\Industrial_1017.jpg', '../../pics/2750/Industrial\\Industrial_1018.jpg', '../../pics/2750/Industrial\\Industrial_1019.jpg', '../../pics/2750/Industrial\\Industrial_102.jpg', '../../pics/2750/Industrial\\Industrial_1020.jpg', '../../pics/2750/Industrial\\Industrial_1021.jpg', '../../pics/2750/Industrial\\Industrial_1022.jpg', '../../pics/2750/Industrial\\Industrial_1023.jpg', '../../pics/2750/Industrial\\Industrial_1024.jpg', '../../pics/2750/Industrial\\Industrial_1025.jpg', '../../pics/2750/Industrial\\Industrial_1026.jpg', '../../pics/2750/Industrial\\Industrial_1027.jpg', '../../pics/2750/Industrial\\Industrial_1028.jpg', '../../pics/2750/Industrial\\Industrial_1029.jpg', '../../pics/2750/Industrial\\Industrial_103.jpg', '../../pics/2750/Industrial\\Industrial_1030.jpg', '../../pics/2750/Industrial\\Industrial_1031.jpg', '../../pics/2750/Industrial\\Industrial_1032.jpg', '../../pics/2750/Industrial\\Industrial_1033.jpg', '../../pics/2750/Industrial\\Industrial_1034.jpg', '../../pics/2750/Industrial\\Industrial_1035.jpg', '../../pics/2750/Industrial\\Industrial_1036.jpg', '../../pics/2750/Industrial\\Industrial_1037.jpg', '../../pics/2750/Industrial\\Industrial_1038.jpg', '../../pics/2750/Industrial\\Industrial_1039.jpg', '../../pics/2750/Industrial\\Industrial_104.jpg', '../../pics/2750/Industrial\\Industrial_1040.jpg', '../../pics/2750/Industrial\\Industrial_1041.jpg', '../../pics/2750/Industrial\\Industrial_1042.jpg', '../../pics/2750/Industrial\\Industrial_1043.jpg', '../../pics/2750/Industrial\\Industrial_1044.jpg', '../../pics/2750/Industrial\\Industrial_1045.jpg', '../../pics/2750/Industrial\\Industrial_1046.jpg', '../../pics/2750/Industrial\\Industrial_1047.jpg', '../../pics/2750/Industrial\\Industrial_1048.jpg', '../../pics/2750/Industrial\\Industrial_1049.jpg', '../../pics/2750/Industrial\\Industrial_105.jpg', '../../pics/2750/Industrial\\Industrial_1050.jpg', '../../pics/2750/Industrial\\Industrial_1051.jpg', '../../pics/2750/Industrial\\Industrial_1052.jpg', '../../pics/2750/Industrial\\Industrial_1053.jpg', '../../pics/2750/Industrial\\Industrial_1054.jpg', '../../pics/2750/Industrial\\Industrial_1055.jpg', '../../pics/2750/Industrial\\Industrial_1056.jpg', '../../pics/2750/Industrial\\Industrial_1057.jpg', '../../pics/2750/Industrial\\Industrial_1058.jpg', '../../pics/2750/Industrial\\Industrial_1059.jpg', '../../pics/2750/Industrial\\Industrial_106.jpg', '../../pics/2750/Industrial\\Industrial_1060.jpg', '../../pics/2750/Industrial\\Industrial_1061.jpg', '../../pics/2750/Industrial\\Industrial_1062.jpg', '../../pics/2750/Industrial\\Industrial_1063.jpg', '../../pics/2750/Industrial\\Industrial_1064.jpg', '../../pics/2750/Industrial\\Industrial_1065.jpg', '../../pics/2750/Industrial\\Industrial_1066.jpg', '../../pics/2750/Industrial\\Industrial_1067.jpg', '../../pics/2750/Industrial\\Industrial_1068.jpg', '../../pics/2750/Industrial\\Indu ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 29
#      26 Y = industrial_labels + forest_labels
#      28 dataset_path = "../../pics/2750/"
# ---> 29 transform = ToTensor()
#      30 dataset = ImageFolder(dataset_path, transform=transform)
#      32 dataset.class_to_idx
#
# NameError: name 'ToTensor' is not defined
